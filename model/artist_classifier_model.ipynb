# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/zend1.jpeg')
img.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (225, 225)

# %%
gray
# Out:
# array([[164, 165, 167, ..., 194, 193, 200],
#        [163, 164, 166, ..., 194, 193, 200],
#        [162, 163, 165, ..., 194, 193, 198],
#        ...,
#        [ 63,  63,  62, ..., 148, 134, 140],
#        [ 62,  62,  62, ..., 151, 132, 140],
#        [ 62,  61,  61, ..., 141, 141, 142]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 37,  63, 137, 137]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (37, 63, 137, 137)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/zend1.jpeg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/zend1.jpeg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/zend2.jpeg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/zend2.jpeg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/drake',
#  './dataset/rihanna',
#  './dataset/taylor_swift',
#  './dataset/zendaya']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# drake
# Generating cropped images in folder:  ./dataset/cropped/drake
# rihanna
# Generating cropped images in folder:  ./dataset/cropped/rihanna
# taylor_swift
# Generating cropped images in folder:  ./dataset/cropped/taylor_swift
# zendaya
# Generating cropped images in folder:  ./dataset/cropped/zendaya

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'drake': ['./dataset/cropped/drake/drake1.png',
#   './dataset/cropped/drake/drake2.png',
#   './dataset/cropped/drake/drake3.png',
#   './dataset/cropped/drake/drake4.png',
#   './dataset/cropped/drake/drake5.png',
#   './dataset/cropped/drake/drake6.png',
#   './dataset/cropped/drake/drake7.png',
#   './dataset/cropped/drake/drake8.png',
#   './dataset/cropped/drake/drake9.png',
#   './dataset/cropped/drake/drake10.png',
#   './dataset/cropped/drake/drake11.png',
#   './dataset/cropped/drake/drake12.png',
#   './dataset/cropped/drake/drake13.png',
#   './dataset/cropped/drake/drake14.png',
#   './dataset/cropped/drake/drake15.png',
#   './dataset/cropped/drake/drake16.png',
#   './dataset/cropped/drake/drake17.png',
#   './dataset/cropped/drake/drake18.png',
#   './dataset/cropped/drake/drake19.png',
#   './dataset/cropped/drake/drake20.png',
#   './dataset/cropped/drake/drake21.png'],
#  'rihanna': ['./dataset/cropped/rihanna/rihanna1.png',
#   './dataset/cropped/rihanna/rihanna2.png',
#   './dataset/cropped/rihanna/rihanna3.png',
#   './dataset/cropped/rihanna/rihanna4.png',
#   './dataset/cropped/rihanna/rihanna5.png',
#   './dataset/cropped/rihanna/rihanna6.png',
#   './dataset/cropped/rihanna/rihanna7.png',
#   './dataset/cropped/rihanna/rihanna8.png',
#   './dataset/cropped/rihanna/rihanna9.png',
#   './dataset/cropped/rihanna/rihanna10.png',
#   './dataset/cropped/rihanna/rihanna11.png',
#   './dataset/cropped/rihanna/rihanna12.png',
#   './dataset/cropped/rihanna/rihanna13.png',
#   './dataset/cropped/rihanna/rihanna14.png',
#   './dataset/cropped/rihanna/rihanna15.png',
#   './dataset/cropped/rihanna/rihanna16.png',
#   './dataset/cropped/rihanna/rihanna17.png',
#   './dataset/cropped/rihanna/rihanna18.png'],
#  'taylor_swift': ['./dataset/cropped/taylor_swift/taylor_swift1.png',
#   './dataset/cropped/taylor_swift/taylor_swift2.png',
#   './dataset/cropped/taylor_swift/taylor_swift3.png',
#   './dataset/cropped/taylor_swift/taylor_swift4.png',
#   './dataset/cropped/taylor_swift/taylor_swift5.png',
#   './dataset/cropped/taylor_swift/taylor_swift6.png',
#   './dataset/cropped/taylor_swift/taylor_swift7.png',
#   './dataset/cropped/taylor_swift/taylor_swift8.png',
#   './dataset/cropped/taylor_swift/taylor_swift9.png',
#   './dataset/cropped/taylor_swift/taylor_swift10.png'],
#  'zendaya': ['./dataset/cropped/zendaya/zendaya1.png',
#   './dataset/cropped/zendaya/zendaya2.png',
#   './dataset/cropped/zendaya/zendaya3.png',
#   './dataset/cropped/zendaya/zendaya4.png',
#   './dataset/cropped/zendaya/zendaya5.png',
#   './dataset/cropped/zendaya/zendaya6.png',
#   './dataset/cropped/zendaya/zendaya7.png',
#   './dataset/cropped/zendaya/zendaya8.png',
#   './dataset/cropped/zendaya/zendaya9.png',
#   './dataset/cropped/zendaya/zendaya10.png',
#   './dataset/cropped/zendaya/zendaya11.png',
#   './dataset/cropped/zendaya/zendaya12.png',
#   './dataset/cropped/zendaya/zendaya13.png',
#   './dataset/cropped/zendaya/zendaya14.png',
#   './dataset/cropped/zendaya/zendaya15.png',
#   './dataset/cropped/zendaya/zendaya16.png',
#   './dataset/cropped/zendaya/zendaya17.png',
#   './dataset/cropped/zendaya/zendaya18.png',
#   './dataset/cropped/zendaya/zendaya19.png',
#   './dataset/cropped/zendaya/zendaya20.png',
#   './dataset/cropped/zendaya/zendaya21.png',
#   './dataset/cropped/zendaya/zendaya22.png',
#   './dataset/cropped/zendaya/zendaya23.png',
#   './dataset/cropped/zendaya/zendaya24.png',
#   './dataset/cropped/zendaya/zendaya25.png',
#   './dataset/cropped/zendaya/zendaya26.png',
#   './dataset/cropped/zendaya/zendaya27.png',
#   './dataset/cropped/zendaya/zendaya28.png',
#   './dataset/cropped/zendaya/zendaya29.png',
#   './dataset/cropped/zendaya/zendaya30.png',
#   './dataset/cropped/zendaya/zendaya31.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'drake': 0, 'rihanna': 1, 'taylor_swift': 2, 'zendaya': 3}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[173],
#        [ 88],
#        [  8],
#        ...,
#        [  0],
#        [  0],
#        [  0]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (80, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.85

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.75      0.60      0.67         5
#            2       1.00      1.00      1.00         3
#            3       0.80      0.89      0.84         9
#
#     accuracy                           0.85        20
#    macro avg       0.89      0.87      0.88        20
# weighted avg       0.85      0.85      0.85        20

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.816667
# 1        random_forest    0.766667
# 2  logistic_regression    0.800000
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[3, 0, 0, 0],
#        [0, 5, 0, 0],
#        [0, 0, 3, 0],
#        [0, 2, 0, 7]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'drake': 0, 'rihanna': 1, 'taylor_swift': 2, 'zendaya': 3}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\rinku\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
